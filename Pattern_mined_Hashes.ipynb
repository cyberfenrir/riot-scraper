# %%
# !pip install pymining
# !pip install tweepy
# !pip install apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-cp36-none-any.whl size=5975 sha256=484855aed6aeccd7feb6687c947655f0b06978bb303a6af59fe0a6917171f081
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# ...

# %%
import string
import tweepy
import re
import csv
import pandas as pd
import io
from google.colab import drive
drive.mount("/content/drive/")
####input your credentials here
consumer_key = 'QTQIqQMHJm80BkjNPFuH0E0GA'
consumer_secret = 'Lx95Hc1mCAftd7H1ROs2bLueCRlIcqTKQdmNwSoxbNy8XkFYpM'
access_token = '764268032160137220-dLQkk0wV451jnco0cEhGwImnQe38d28'
access_token_secret = 'PUlFQpIct8kRBVAY8KODtfh7xmnH5R78lxOv7vvty8i6q'
 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
#####United Airlines
# Open/Create a file to append data
csvFile = open('ua.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)
full=[]
for tweet in tweepy.Cursor(api.search,q="#riot",count=500,
                           lang="en",
                           since="2010-04-03").items():
    #print (tweet.created_at, tweet.text)
    row=re.findall(r"#(\w+)",(tweet.text).lower())
    if row:
      full.append(row)
for tweet in tweepy.Cursor(api.search,q="#protest",count=500,
                           lang="en",
                           since="2010-04-03").items():
    #print (tweet.created_at, tweet.text)
    row=re.findall(r"#(\w+)",(tweet.text).lower())
    if row:
      full.append(row)
for tweet in tweepy.Cursor(api.search,q="#uproar",count=500,
                           lang="en",
                           since="2010-04-03").items():
    #print (tweet.created_at, tweet.text)
    row=re.findall(r"#(\w+)",(tweet.text).lower())
    if row:
      full.append(row)
for tweet in tweepy.Cursor(api.search,q="#opposition",count=500,
                           lang="en",
                           since="2010-04-03").items():
    #print (tweet.created_at, tweet.text)
    row=re.findall(r"#(\w+)",(tweet.text).lower())
    if row:
      full.append(row)
    
 
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
 
print(full)
fulldata = pd.DataFrame(full)
print(fulldata)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# ...

# %%
ful1 = [i for i in full if i]
ful2 = []
#hashtag=[]
#hashes=[]
for i in range (0,len(ful1)):
  for j in ful1[i]:
    if ((("valorant" not in j.lower()) and ("game" not in j.lower())) and (("riot" in j.lower()) or ("protest" in j.lower()) or ("uproar" in j.lower()) or ("opposition" in j.lower()))):
#      for k in ful1[i]:
#        hashtag.append(k)
      ful2.append(ful1[i])
      break
#[hashes.append(x) for x in hashtag if x not in hashes]
#print(len(hashes),hashes)
print(len(ful2),ful2)
# Out:
# 11884 [['riot', 'league'], ['delhiriotsuntoldstory', 'fraud', 'fraudster', 'riot'], ['nf', 'nottingham', 'riot'], ['riot', 'chh'], ['quietriot', 'riot'], ['riotgames', 'riot'], ['trump', 'republicans', 'conservative', 'protesters'], ['delhi', 'bangalore', 'riot'], ['portland', 'portlandriots', 'riot', 'riots', 'protest', 'protests', 'antifa', 'blacklivesmatter', 'pdx', 'friday', 'fridaythou'], ['protest', 'riot', 'law', 'banning', 'greece', 'provisions'], ['police', 'riot', 'portland', 'protests'], ['riot'], ['protest', 'riot', 'live'], ['blm', 'riot', 'caught'], ['forestrat', 'art', 'leagueoflegends', 'nidalee', 'neeko', 'neekoxnidalee', 'cat', 'cats', 'cougar', 'riot', 'riotgames', 'lol', 'lolfanar'], ['snackvan', 'riot'], ['portland', 'portlandriots', 'riot'], ['riot', 'canucks'], ['snackvan', 'riot'], ['portlandriots'], ['portland', 'portlandriots', 'riot', 'riots', 'protest', 'protests', 'antifa', 'blacklivesmatter', 'pdx', 'friday'], ['protest', 'riot', 'live'], ['riot', 'canuc
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

association_rules = apriori(ful2,min_support = 0.0032, min_confidence = 0.2, min_lift = 2, min_length = 2, max_length = 2)
results = list(association_rules)
results
# Out:
# [RelationRecord(items=frozenset({'london', '3point5percent'}), support=0.00429148434870414, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3point5percent'}), items_add=frozenset({'london'}), confidence=0.9107142857142857, lift=38.108903420523134)]),
#  RelationRecord(items=frozenset({'3point5percent', 'occupy'}), support=0.0043756311006395154, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3point5percent'}), items_add=frozenset({'occupy'}), confidence=0.9285714285714286, lift=38.856136820925556)]),
#  RelationRecord(items=frozenset({'3point5percent', 'revolt'}), support=0.0043756311006395154, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3point5percent'}), items_add=frozenset({'revolt'}), confidence=0.9285714285714286, lift=37.921453117329406)]),
# ...

# %%
def inspect(results):
   return list(map(lambda el:[el], results)) 
   print(inspect(results))

# %%
hashtag1=[]
hashtag2=[]
hashes1=[]
hashes2=[]
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    finallist=[]
    for i in range(0,len(lhs)):
      finals=[]
      finals.append(lhs[i])
      finals.append(rhs[i])
      finallist.append(finals)
    print(finallist)
#    for i in rhs:
#      if i not in hashes:
#        hashes.append(i)
#    for i in hashes:
#      if(("valorant" in i) or ("game" in i) or ("leagueoflegends" in i)):
#        hashes.remove(i)
    for i in range(0,len(finallist)):
#      count = success = 0
      for j in finallist[i]:
#        count = count + 1
        if ((("valorant" not in j.lower()) and ("game" not in j.lower())) and (("riot" in j.lower()) or ("revolt" in j.lower()) or ("protes" in j.lower()) or ("uproar" in j.lower()) or ("opposition" in j.lower()))):
#          success = success + 1
          for k in finallist[i]:
            hashtag1.append(k)
          break
#        if(count == 2 and success == 0):
#          for k in finallist[i]:
#            hashtag2.append(k)
#          break
    [hashes1.append(x) for x in hashtag1 if x not in hashes1]
#    [hashes2.append(x) for x in hashtag2 if x not in hashes2]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])
for i in range(len(hashes1)):
  if(("valorant" in hashes1[i]) or ("game" in hashes1[i]) or ("leagueoflegends" in hashes1[i]) or ("shopping" in hashes1[i])):
#    if hashes1[i] not in hashes2:
#      hashes2.append(hashes1[i])
    hashes1[i] = ' '
  hashes = (' '.join(hashes1)).split()
#for i in range(len(hashes)):
#  for j in range(len(hashes2)):
#    if (hashes[i] == hashes2[j]):
#      hashes2[j] = ' '
#hashesx = (' '.join(hashes2)).split()
#hashesx.append("riotgames")
dff = (pd.DataFrame(hashes))
hashesx = ["valo","valorant","riotgames","legends","leagueoflegends","runeterra","sage","jett","omen","jinx","ahri","usa","grocery","shopping","groceryshopping","styleinspo","emailmarketing","love","coronavirus","photography","influencer","wcw","tbt","fridayfeeling","cricket","volleyball","rosecity","virginia","richmond","monument","london","chicago","happy","puppy","dogs","pets","cats","photooftheday","nofilter","swag",]
dff1 = (pd.DataFrame(hashesx))
print(len(hashes),hashes)
print(len(hashesx),hashesx)
dff.to_csv('/content/drive/My Drive/Riot Project/HashtagList1.csv',index=False)
dff1.to_csv('/content/drive/My Drive/Riot Project/HashtagList0.csv',index=False)
# Out:
# [['3point5percent', 'london'], ['3point5percent', 'occupy'], ['3point5percent', 'revolt'], ['a', 'blacklivesmatter'], ['a', 'blm'], ['a', 'oregon'], ['a', 'pdx'], ['a', 'portland'], ['absenteeballot', 'vote'], ['ac', 'blacklivesmatter'], ['ac', 'blm'], ['ac', 'oregon'], ['ac', 'pdx'], ['ac', 'portland'], ['acab', 'blacklivesmatter'], ['acab', 'blm'], ['i', 'acab'], ['acab', 'oregon'], ['p', 'acab'], ['acab', 'pdx'], ['port', 'acab'], ['portla', 'acab'], ['portlan', 'acab'], ['acab', 'portland'], ['portlandpro', 'acab'], ['portlandprote', 'acab'], ['acab', 'portlandprotests'], ['portlandstr', 'acab'], ['portlandstrong', 'acab'], ['alevelprotests', 'alevels2020'], ['alevelprotests', 'gcses2020'], ['alevelresults20', 'alevelresultsday'], ['alevelresults20', 'examshambles'], ['alevelresultsday', 'examshambles'], ['alevels2020', 'gcses2020'], ['antifa', 'portland'], ['antifa', 'portlandriots'], ['antifa', 'protests'], ['antifa', 'riot'], ['antifa', 'riots'], ['baraulyany', 'belarus'], ['b
# ...

# %%
print(dff)
# Out:
#                         0
# 0          3point5percent
# 1                  revolt
# 2                    acab
# 3        portlandprotests
# 4          alevelprotests
# 5             alevels2020
# 6               gcses2020
# 7                  antifa
# 8           portlandriots
# 9                protests
# 10                   riot
# 11                  riots
# 12            pdxprotests
# 13       blacklivesmatter
# 14           protests2020
# 15  blacklivesmatterplaza
# 16             dcprotests
# 17                    blm
# 18                chicago
# 19                covid19
# 20                     dc
# 21              democrats
# 22                      i
# 23                 london
# 24                   loot
# 25        mail_in_votiing
# 26                 occupy
# 27                 oregon
# 28                      p
# 29                    pdx
# 30                  prote
# 31                 police
# 32                   port
# 33               portland
# ...

# %%
resultsinDataFrame.nlargest(n = 100, columns = 'Support')
# Out:
#        Left Hand Side   Right Hand Side   Support  Confidence       Lift
# 55   blacklivesmatter               pdx  0.277348    0.871266   3.009046
# 142               pdx          portland  0.222568    0.768672   3.215381
# 62   blacklivesmatter          portland  0.212639    0.667988   2.794218
# 127            oregon          portland  0.206412    0.998779   4.177925
# 122            oregon               pdx  0.205739    0.995521   3.438179
# ..                ...               ...       ...         ...        ...
# 162       portlandstr          portland  0.006900    1.000000   4.183034
# 167       portlandstr  portlandprotests  0.006900    1.000000  11.931727
# 18                  p              acab  0.006732    0.366972   2.995262
# 135                 p  portlandprotests  0.006732    0.366972   4.378615
# 172     portlandriots              riot  0.006563    0.327731   4.174444
#
# [100 rows x 5 columns]
